# %% [markdown]
# # Tree Traversals
# After know about the tree data stucture, we should know how to access the nodes of the tree.
# ## Three ways
# - preorder
#
# - inorder
#
# - postorder
#
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %%
class BinaryTree:
    
    def __init__(self,root_obj):
        self.key = root_obj
        self.left_child = None
        self.right_child = None
        
    def insert_left(self,new_node):
        if self.left_child is None:
            self.left_child = BinaryTree(new_node) # left node is also a tree
        else:
            new_child = BinaryTree(new_node)
            new_child.left_child = self.left_child
            self.left_child = new_child
            
    def insert_right(self,new_node):
        if self.right_child is None:
            self.right_child = BinaryTree(new_node)
        else:
            new_child = BinaryTree(new_node)
            new_child.right_child = self.right_child
            self.right_child = new_child
   
    def get_root_val(self):
        return self.key
    
    def set_root_val(self,new_obj):
        self.key = new_obj
        
    def get_left_child(self):
        return self.left_child
    
    def get_right_child(self):
        return self.right_child

# %% [markdown]
# ### Preorder
# ![ChessUrl](https://img-blog.csdnimg.cn/20200429123312712.gif)
# Implementing preorder as an external function is better

# %%
tree = BinaryTree("")
def perorder(tree):
    if tree:
        print(tree.get_root_val())
        preorder(tree.get_left_child())
        preorder(tree.get_right_child())

# %% [markdown]
# ### Postorder
# Can use to evaluate the parse tree
# ![ChessUrl](https://img-blog.csdnimg.cn/20200429123504470.gif)

# %%
def postorder(tree):
    if tree:
        postorder(tree.get_left_child())
        postorder(tree.get_right_child())
        print(tree.get_root_val())

# %% [markdown]
# ### Inorder
# ![ChessUrl](https://img-blog.csdnimg.cn/20200429123443327.gif)

# %%
def inorder(tree):
    if tree:
        inorder(tree.get_left_child())
        print(tree.get_root_val())
        inorder(tree.get_right_child())
